# %%
import base64
text = """
echo "ZmluZCAvaG9tZS9jdGYgLXR5cGUgZiAtbmFtZSAiRiIgMj4vZGV2L251bGw=" | base64 -d | bash
echo "ZmluZCAvaG9tZS9jdGYgLXR5cGUgZiAtbmFtZSAiQyIgMj4vZGV2L251bGw=" | base64 -d | bash
echo "ZmluZCAvaG9tZS9jdGYgLXR5cGUgZiAtbmFtZSAiQyIgMj4vZGV2L251bGw=" | base64 -d | bash
echo "ZmluZCAvaG9tZS9jdGYgLXR5cGUgZiAtbmFtZSAiVCIgMj4vZGV2L251bGw=" | base64 -d | bash
echo "ZmluZCAvaG9tZS9jdGYgLXR5cGUgZiAtbmFtZSAiRiIgMj4vZGV2L251bGw=" | base64 -d | bash
echo "ZmluZCAvaG9tZS9jdGYgLXR5cGUgZiAtbmFtZSAieyIgMj4vZGV2L251bGw=" | base64 -d | bash
echo "ZmluZCAvaG9tZS9jdGYgLXR5cGUgZiAtbmFtZSAiYiIgMj4vZGV2L251bGw=" | base64 -d | bash
echo "ZmluZCAvaG9tZS9jdGYgLXR5cGUgZiAtbmFtZSAiNCIgMj4vZGV2L251bGw=" | base64 -d | bash
echo "ZmluZCAvaG9tZS9jdGYgLXR5cGUgZiAtbmFtZSAicyIgMj4vZGV2L251bGw=" | base64 -d | bash
echo "ZmluZCAvaG9tZS9jdGYgLXR5cGUgZiAtbmFtZSAicyIgMj4vZGV2L251bGw=" | base64 -d | bash
echo "ZmluZCAvaG9tZS9jdGYgLXR5cGUgZiAtbmFtZSAiMyIgMj4vZGV2L251bGw=" | base64 -d | bash
echo "ZmluZCAvaG9tZS9jdGYgLXR5cGUgZiAtbmFtZSAiXyIgMj4vZGV2L251bGw=" | base64 -d | bash
echo "ZmluZCAvaG9tZS9jdGYgLXR5cGUgZiAtbmFtZSAiNiIgMj4vZGV2L251bGw=" | base64 -d | bash
echo "ZmluZCAvaG9tZS9jdGYgLXR5cGUgZiAtbmFtZSAiNCIgMj4vZGV2L251bGw=" | base64 -d | bash
Value: echo "ZmluZCAvaG9tZS9jdGYgLXR5cGUgZiAtbmFtZSAiXyIgMj4vZGV2L251bGw=" | base64 -d | bash
Value: echo "ZmluZCAvaG9tZS9jdGYgLXR5cGUgZiAtbmFtZSAiaSIgMj4vZGV2L251bGw=" | base64 -d | bash
Value: echo "ZmluZCAvaG9tZS9jdGYgLXR5cGUgZiAtbmFtZSAicyIgMj4vZGV2L251bGw=" | base64 -d | bash
Value: echo "ZmluZCAvaG9tZS9jdGYgLXR5cGUgZiAtbmFtZSAibiIgMj4vZGV2L251bGw=" | base64 -d | bash
Value: echo "ZmluZCAvaG9tZS9jdGYgLXR5cGUgZiAtbmFtZSAidCIgMj4vZGV2L251bGw=" | base64 -d | bash
Value: echo "ZmluZCAvaG9tZS9jdGYgLXR5cGUgZiAtbmFtZSAiXyIgMj4vZGV2L251bGw=" | base64 -d | bash
Value: echo "ZmluZCAvaG9tZS9jdGYgLXR5cGUgZiAtbmFtZSAidCIgMj4vZGV2L251bGw=" | base64 -d | bash
Value: echo "ZmluZCAvaG9tZS9jdGYgLXR5cGUgZiAtbmFtZSAiaCIgMj4vZGV2L251bA==" | base64 -d | bash
Value: echo "ZmluZCAvaG9tZS9jdGYgLXR5cGUgZiAtbmFtZSAiYSIgMj4vZGV2L251bGw=" | base64 -d | bash
Value: echo "ZmluZCAvaG9tZS9jdGYgLXR5cGUgZiAtbmFtZSAidCIgMj4vZGV2L251bGw=" | base64 -d | bash
Value: echo "ZmluZCAvaG9tZS9jdGYgLXR5cGUgZiAtbmFtZSAiXyIgMj4vZGV2L251bGw=" | base64 -d | bash
Value: echo "ZmluZCAvaG9tZS9jdGYgLXR5cGUgZiAtbmFtZSAiZyIgMj4vZGV2L251bGw=" | base64 -d | bash
Value: echo "ZmluZCAvaG9tZS9jdGYgLXR5cGUgZiAtbmFtZSAiMCIgMj4vZGV2L251bGw=" | base64 -d | bash
Value: echo "ZmluZCAvaG9tZS9jdGYgLXR5cGUgZiAtbmFtZSAiMCIgMj4vZGV2L251bGw=" | base64 -d | bash
Value: echo "ZmluZCAvaG9tZS9jdGYgLXR5cGUgZiAtbmFtZSAiZCIgMj4vZGV2L251bGw=" | base64 -d | bash
Value: echo "ZmluZCAvaG9tZS9jdGYgLXR5cGUgZiAtbmFtZSAifSIgMj4vZGV2L251bGw=" | base64 -d | bash
"""
s = []
for command in text.split('\n'):
    command = command.strip()
    if command:
        base64_string = command.split('"')[1]
        decoded_base64_string = base64.b64decode(base64_string).decode()
        s.append(decoded_base64_string.split('"')[1])
''.join(s)
# Out:
# 'FCCTF{b4ss3_64_isnt_that_g00d}'

# %%
import pandas as pd

pd.read_csv('packets.csv')

# %%
packets[packets.Info.apply(lambda x: '443  >' in x)]
# Out:
#          No.        Time           Source     Destination Protocol  Length  \
# 6          7    0.889309  142.250.187.138  192.168.71.129      TCP      66
# 7          8    0.889309   172.217.17.131  192.168.71.129      TCP      66
# 23645  23646   31.411534    216.58.212.36  192.168.71.129      TCP      66
# 23650  23651   31.412824    216.58.212.36  192.168.71.129      TCP      66
# 23651  23652   31.413023    216.58.212.36  192.168.71.129      TCP      66
# ...      ...         ...              ...             ...      ...     ...
# 56432  56433  270.393906  142.250.187.163  192.168.71.129      TCP      66
# 56454  56455  271.184174    18.156.16.255  192.168.71.129      TCP      66
# 56462  56463  271.344376    74.125.162.72  192.168.71.129      TCP      66
# 56464  56465  271.379784    74.125.162.72  192.168.71.129      TCP      66
# 56466  56467  271.472514    74.125.162.72  192.168.71.129      TCP      66
#
#                                                     Info
# ...

# %%
packets[packets.Info.apply(lambda x: 'flag' in x)]
# Out:
#          No.       Time     Source Destination Protocol  Length  \
# 13802  13803  16.546046  127.0.0.1   127.0.0.1     HTTP     343
# 13804  13805  16.550855  127.0.0.1   127.0.0.1     HTTP     343
# 13806  13807  16.551860  127.0.0.1   127.0.0.1     HTTP     344
# 13808  13809  16.552316  127.0.0.1   127.0.0.1     HTTP     343
# 13810  13811  16.552746  127.0.0.1   127.0.0.1     HTTP     344
# 13812  13813  16.556425  127.0.0.1   127.0.0.1     HTTP     342
# 13818  13819  16.560887  127.0.0.1   127.0.0.1     HTTP     340
# 16330  16331  19.230779  127.0.0.1   127.0.0.1     HTTP     351
# 16332  16333  19.232990  127.0.0.1   127.0.0.1     HTTP     355
# 16334  16335  19.235145  127.0.0.1   127.0.0.1     HTTP     352
#
#                                       Info
# 13802              GET /flag.txt HTTP/1.1
# 13804              GET /flag.php HTTP/1.1
# 13806             GET /flag.aspx HTTP/1.1
# 13808              GET /flag.jsp HTTP/1.1
# 13810             GET /flag.html HTTP/1.1
# ...

# %%
packets.Source.value_counts().head(50)
# Out:
# Source
# 127.0.0.1          24308
# 192.168.71.129     10068
# 104.18.7.84         4991
# 216.58.212.36       4108
# 216.58.212.14       1886
# 216.58.214.131      1227
# 172.217.17.110       808
# 136.255.251.109      758
# 162.159.153.4        711
# 136.255.251.111      668
# 127.0.0.53           549
# 172.217.17.131       472
# 74.125.162.72        394
# 104.18.3.117         367
# 192.168.71.2         366
# 142.251.140.40       338
# 18.165.171.78        318
# 142.250.184.150      301
# 151.101.65.69        235
# 172.217.17.98        220
# 185.85.0.29          215
# 18.156.16.255        152
# 185.199.111.154      144
# 142.251.140.74       113
# 142.250.187.138      107
# 216.58.212.42        105
# 162.159.152.4        102
# 142.251.140.78        99
# 185.199.110.133       96
# 18.165.171.86         93
# 46.97.92.81           86
# 172.217.20.78         84
# 172.217.169.110       83
# 104.18.169.114        79
# 172.217.17.106        76
# 172.217.17.97         76
# ...
