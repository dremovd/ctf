# %%
URL = "chals.sekai.team:3001"

import utils
import socket
import sys
import time


class CryptoClient:
    def __init__(self, connection: str):
        self.ip, self.port = connection.split(":")
        self.port = int(self.port)
        self.sock = None
        self.key = None
        self.buffer = ""  # Initialize an empty buffer

    def connect(self):
        self.sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
        try:
            self.sock.connect((self.ip, self.port))
        except ConnectionError:
            print("Failed to connect to server.")
            sys.exit(1)
        print("CONNECTED")

    def read_line(self):
        while "\n" not in self.buffer:
            try:
                data = self.sock.recv(1024).decode('utf-8')
                if not data:
                    return None
                self.buffer += data
            except socket.error:
                return None
        line, self.buffer = self.buffer.split("\n", 1)
        return line

    def receive_key(self):
        line = self.read_line()
        if line:
            self.key = bytes.fromhex(line.split(':')[-1].strip())
        else:
            print("Failed to receive data from server.")
            sys.exit(1)
        print(f"KEY: {self.key.hex()}")

    def skip_until(self, text, debug=True):
        time.sleep(1)
        while True:
            line = self.read_line()
            if debug and line:
                print(line)
            if line and text in line:
                break

    def receive_query(self):
        line = self.read_line()
        if line:
            values = line.split(': ')[-1].split()
            query_from, query_to = map(int, values)
        else:
            print("Failed to receive data from server.")
            sys.exit(1)
        print(f"QUERY: {query_from} -> {query_to}")
        return query_from, query_to

    def receive_response(self):
        line = self.read_line()
        if line:
            encrypted_response = bytes.fromhex(line.split('Response: ')[-1].strip())
        else:
            print("Failed to receive data from server.")
            sys.exit(1)
        print(f"ENCRYPTED RESPONSE: {encrypted_response.hex()}")
        return encrypted_response
    
    def send_response(self, response: str):
        try:
            self.sock.sendall((response + "\n").encode('utf-8'))
        except socket.error:
            print("Failed to send data to server.")
            sys.exit(1)
        print(f"SENT RESPONSE: {response}")
    
SECURITY_PARAMETER = 16

def decrypt(u: int, v: int, key: bytes, resp: bytes) -> str:
    """
    Decrypts the response to reveal the shortest path between nodes in the graph.

    Parameters:
    u (int): The source node
    v (int): The destination node
    resp (bytes): The encrypted response from the server
    key (bytes): The secret key used for decryption

    Returns:
    str: The decrypted shortest path as a space-separated string
    """
    # Extract Subkeys
    key_SKE = key[:SECURITY_PARAMETER]
    key_DES = key[SECURITY_PARAMETER:]
    
    # Initialize Variables
    path = [u]
    # Decryption Loop
    segment_size = 32  # Assuming each encrypted node is 32 bytes
    for i in range(0, len(resp), segment_size):
        # Decrypt the segment
        block = resp[i:i+segment_size]
        decrypted_segment = utils.SymmetricDecrypt(key_SKE, block)
        
        # Path Extraction
        # Assuming decrypted_segment contains the node as bytes
        node1, node2 = map(int, decrypted_segment.decode().split(','))
        path.append(node1)
        
    # Validate the path starts at 'u' and ends at 'v'
    if path[0] != u or path[-1] != v:
        return "Invalid path"
    
    # Return Result
    return " ".join(map(str, path))


if __name__ == "__main__":
    client = CryptoClient(URL)
    client.connect()
    client.skip_until('Generating random graph', debug=False)
    client.receive_key()
    client.skip_until('Answer 50 queries', debug=False)
    
    for i in range(50):
        query_from, query_to = client.receive_query()
        encrypted_response = client.receive_response()
        decrypted_response = decrypt(query_from, query_to, client.key, encrypted_response)
        print(f"Decrypted response: {decrypted_response}")
        # Send the decrypted response back to the server
        client.send_response(decrypted_response)
    client.skip_until("Flag:")
# Out:
# CONNECTED
# KEY: fac49a99920a6fd0175bffe083722e3ba606be19c8f4954ca6fb9293f2bdc2a0
# QUERY: 68 -> 39
# ENCRYPTED RESPONSE: 
# Decrypted response: 68 25 78 116 76 39
# SENT RESPONSE: 68 25 78 116 76 39
# QUERY: 57 -> 74
# ENCRYPTED RESPONSE: 38047e26e67dba9b30b6c60201037e949d41f897f155239023cc8b400ce629637bcffe5d60f27fb33645a07455a47936a906cafc911ba0f7ddbad68061d3078c
# Decrypted response: 57 113 74
# SENT RESPONSE: 57 113 74
# QUERY: 20 -> 78
# ENCRYPTED RESPONSE: 
# Decrypted response: 20 110 2 7 78
# SENT RESPONSE: 20 110 2 7 78
# QUERY: 13 -> 67
# ENCRYPTED RESPONSE: 
# Decrypted response: 13 98 78 129 72 67
# SENT RESPONSE: 13 98 78 129 72 67
# QUERY: 54 -> 122
# ENCRYPTED RESPONSE: 
# Decrypted response: 54 111 23 118 122
# SENT RESPONSE: 54 111 23 118 122
# QUERY: 80 -> 109
# ENCRYPTED RESPONSE: d12aeb527b7b05348ac2f0f6e6cc53a7ac11f657d58bceb6727e9a73593435744580845cf57daa207144454c0c9a63718fd7a69375ccb05adf69f8500a531c364916cc10343c38ffe23d9ec728ddd745c00dca24a46fb60d9bfc45d0a7d471c1
# Decrypted response: 80 16 87 109
# SENT RESPONSE: 80 16 87 109
# QUERY: 46 -> 95
# ENCRYPTED RESPONSE: 28409bcdfc030e2021422c19497075ccf69a0a9819a256bb5336e2d0d696e9c1a923fb013c88070f6f24bba245425e61c9553e2da0f99f8c6bfa326ffd7d17c2b8253f6f9c1453922cd0017044cec39d4aaa6f5593043717ba56e2b2a704a058
# Decrypted response: 46 124 96 95
# SENT RESPONSE: 46 124 96 95
# QUERY: 79 -> 34
# ENCRYPTED RESPONSE: 
# Decrypted response: 79 74 30 94 61 34
# SENT RESPONSE: 79 74 30 94 61 34
# QUERY: 68 -> 98
# ENCRYPTED RESPONSE: 719af54254099e47bb6347d727ffac216b0197145deaecd78d61deab075dc37757503ad3fb5670a901c1ff4f73bc0ae384d3429e883e6038944326f2fbef9223459f9108ba5a65b220e87cf6d70184a8e9a2aa814d79f2641475ccc939d3fc9c
# Decrypted response: 68 25 78 98
# SENT RESPONSE: 68 25 78 98
# QUERY: 49 -> 71
# ENCRYPTED RESPONSE: 683af98b4354382c4cdacb91bc083a166b2dfcd8aea2081145030d53cad269cc7e3caeddf033c32af55a1430d3df026e2bc81acfd4249b5319203b888440b2ac4dd8a20688a21fe2e028facfb7e0ee53d3eeade0d509f413345b5c9cc7eac975
# Decrypted response: 49 62 119 71
# SENT RESPONSE: 49 62 119 71
# QUERY: 16 -> 124
# ENCRYPTED RESPONSE: 
# Decrypted response: 16 126 120 59 124
# SENT RESPONSE: 16 126 120 59 124
# QUERY: 67 -> 117
# ENCRYPTED RESPONSE: 
# Decrypted response: 67 32 17 10 117
# SENT RESPONSE: 67 32 17 10 117
# QUERY: 94 -> 115
# ENCRYPTED RESPONSE: 
# Decrypted response: 94 30 111 54 115
# SENT RESPONSE: 94 30 111 54 115
# QUERY: 108 -> 61
# ENCRYPTED RESPONSE: 
# Decrypted response: 108 80 37 114 61
# SENT RESPONSE: 108 80 37 114 61
# QUERY: 9 -> 71
# ENCRYPTED RESPONSE: 
# Decrypted response: 9 49 62 119 71
# SENT RESPONSE: 9 49 62 119 71
# QUERY: 24 -> 70
# ENCRYPTED RESPONSE: 6a9fa2b5396629821a8e172d65d8a6fb6331a2abc8086da327a29f1409b668ece1c2606d35435d6790c7670a3be3893bdc7cb8f7de36fd6c8480dcf43e91c41a7071970f28fbf9883f8dee4f216b5ee4c3393c09ae97c5b6ef52c7b79ce06cd1
# Decrypted response: 24 120 71 70
# SENT RESPONSE: 24 120 71 70
# QUERY: 108 -> 38
# ENCRYPTED RESPONSE: a9efb333abc33cfd80eb22906ccf3bde942535f67be97fad4e281fd4907e9f6a9401dc7f2808962e205c3c3c364b1b4868ec18a11e30f1a44f020329ea8df14fe088e1d76ee20d73ab0ac9141b1927c1a3e7ff45e901b25aa40707ae30fcdf6c
# Decrypted response: 108 128 27 38
# SENT RESPONSE: 108 128 27 38
# QUERY: 41 -> 16
# ENCRYPTED RESPONSE: 
# Decrypted response: 41 7 78 129 16
# SENT RESPONSE: 41 7 78 129 16
# QUERY: 3 -> 30
# ENCRYPTED RESPONSE: 
# Decrypted response: 3 47 61 94 30
# SENT RESPONSE: 3 47 61 94 30
# QUERY: 125 -> 82
# ENCRYPTED RESPONSE: 
# Decrypted response: 125 33 38 31 127 82
# SENT RESPONSE: 125 33 38 31 127 82
# QUERY: 73 -> 78
# ENCRYPTED RESPONSE: 
# Decrypted response: 73 31 119 129 78
# SENT RESPONSE: 73 31 119 129 78
# QUERY: 22 -> 75
# ENCRYPTED RESPONSE: 
# Decrypted response: 22 116 78 98 75
# SENT RESPONSE: 22 116 78 98 75
# QUERY: 70 -> 69
# ENCRYPTED RESPONSE: 
# Decrypted response: 70 128 30 111 54 69
# SENT RESPONSE: 70 128 30 111 54 69
# QUERY: 95 -> 47
# ENCRYPTED RESPONSE: 5f12fc454e808495495e1b586f9aa9fc0bf9f1e4a9b7b73ef0e416675f2adce2d8a65cf8849b19891da741ccc87c334322edf8e6c2dbe138ec10b88d720d0774fa92d77e9ed7f7f8a132f5d5387aebbcc1df4ff16ccec48d0706025ac2ccb15d
# Decrypted response: 95 109 61 47
# SENT RESPONSE: 95 109 61 47
# QUERY: 116 -> 16
# ENCRYPTED RESPONSE: e31775eb7f2af226fe74c75ba2d2ea1f0109b234ed18802828026107b17ac32d35a8eb151bd4ed391360ab4f5e4652f21c8f67a8a7f456d52b6dbcb023f09689438360bdf2731ae6e6dbfee97b301efc964a0dc998e857782cef8a70eda5c829
# Decrypted response: 116 78 129 16
# SENT RESPONSE: 116 78 129 16
# QUERY: 12 -> 12
# ENCRYPTED RESPONSE:
# Decrypted response: 12
# SENT RESPONSE: 12
# QUERY: 70 -> 33
# ENCRYPTED RESPONSE: 20629f13e2a3e6aeaa6b2192c42c8d48048bcbd4745828bd5baba96832af474c909e3f1086a68a4f5bc99c0cf2ff6017cc18a67c8ce0834934fff4774194e3af
# Decrypted response: 70 71 33
# SENT RESPONSE: 70 71 33
# QUERY: 42 -> 32
# ENCRYPTED RESPONSE: 
# Decrypted response: 42 87 97 44 32
# SENT RESPONSE: 42 87 97 44 32
# QUERY: 50 -> 90
# ENCRYPTED RESPONSE: 0f7a5425eb8102bfc174a362f3ebde63e0a5d2d026e3d33d3bd66c50f6c5101be02c523b10998a42da260b40b49fe6eef1fde35b806fb98e2367c2ebfdae46c5
# Decrypted response: 50 81 90
# SENT RESPONSE: 50 81 90
# QUERY: 34 -> 15
# ENCRYPTED RESPONSE: 
# Decrypted response: 34 61 114 37 97 15
# SENT RESPONSE: 34 61 114 37 97 15
# QUERY: 22 -> 74
# ENCRYPTED RESPONSE: d7e0fe6d9b8f20871fbcb1258a2d109ebf183d53bf3f2da309f0c9a57839ee0f7bcffe5d60f27fb33645a07455a47936a906cafc911ba0f7ddbad68061d3078c
# Decrypted response: 22 113 74
# SENT RESPONSE: 22 113 74
# QUERY: 117 -> 63
# ENCRYPTED RESPONSE: 
# Decrypted response: 117 87 113 123 83 63
# SENT RESPONSE: 117 87 113 123 83 63
# QUERY: 118 -> 73
# ENCRYPTED RESPONSE: 
# Decrypted response: 118 122 113 35 73
# SENT RESPONSE: 118 122 113 35 73
# QUERY: 64 -> 46
# ENCRYPTED RESPONSE: 
# Decrypted response: 64 97 37 24 46
# SENT RESPONSE: 64 97 37 24 46
# QUERY: 59 -> 75
# ENCRYPTED RESPONSE: ...
# Decrypted response: 59 120 126 103 115 54 69 75
# SENT RESPONSE: 59 120 126 103 115 54 69 75
# QUERY: 12 -> 123
# ENCRYPTED RESPONSE: 
# Decrypted response: 12 45 118 122 113 123
# SENT RESPONSE: 12 45 118 122 113 123
# QUERY: 113 -> 3
# ENCRYPTED RESPONSE: 697575983bf9d5142f0608cb4458a29950349b2e67da9e84048f0324173abd0de0b5b67c121441bc6c5b1bebb923b0a1b7d97a96238c2e106036e67e08098aa6
# Decrypted response: 113 35 3
# SENT RESPONSE: 113 35 3
# QUERY: 89 -> 121
# ENCRYPTED RESPONSE: 01cc90d9143d950d063e84c160a1d90d5f6e56ff59874fa5595194c43a62e30c7d53f6e57397c27221ca9f9315ff0818fd74ed2e278042de868f66ee469fe749
# Decrypted response: 89 28 121
# SENT RESPONSE: 89 28 121
# QUERY: 97 -> 91
# ENCRYPTED RESPONSE: 
# Decrypted response: 97 122 118 45 91
# SENT RESPONSE: 97 122 118 45 91
# QUERY: 26 -> 123
# ENCRYPTED RESPONSE: 9c34673aa0c5560e6b8d39bf439d3587af84ddc8e9198b5794b6cc107d95aad7123f38d4d1f3bfa7d4c7a46c1131e5b095be67e450eb84b91d443665f2691bb09ca8e647325556f95337555adb815d3e47fadeb6a3801beb18e1b48b65a774d8
# Decrypted response: 26 74 113 123
# SENT RESPONSE: 26 74 113 123
# QUERY: 41 -> 42
# ENCRYPTED RESPONSE: 069e4fc34e7cc2f2322736366a1b2df0d2a662846f6d2a2ee80db52cff7292cf0a198f31a1f46c43e7f491e2283004ea317ac825b95e461756768c7afa0c70939d1d4984298811e29fc8044b31e91ecc2a05f8c3e742cfcb3cf73da2f57ab7b4
# Decrypted response: 41 7 2 42
# SENT RESPONSE: 41 7 2 42
# QUERY: 88 -> 103
# ENCRYPTED RESPONSE: ecc7ea15124e42c7c3e491135c240248c75d8b0e8249bda0bd1e35da846cd0e5fdd309be5f95fda1731a2ac395e7089fd25465cf5fd559493fdd57915dc233222901ad69294e038462bb914752c6a836a1f6eedf01130d7e926d9d653c650201
# Decrypted response: 88 129 57 103
# SENT RESPONSE: 88 129 57 103
# QUERY: 114 -> 75
# ENCRYPTED RESPONSE: 
# Decrypted response: 114 89 78 98 75
# SENT RESPONSE: 114 89 78 98 75
# QUERY: 105 -> 29
# ENCRYPTED RESPONSE: 
# Decrypted response: 105 46 28 1 29
# SENT RESPONSE: 105 46 28 1 29
# QUERY: 74 -> 21
# ENCRYPTED RESPONSE: 
# Decrypted response: 74 113 35 3 21
# SENT RESPONSE: 74 113 35 3 21
# QUERY: 67 -> 83
# ENCRYPTED RESPONSE: 19437c76fa6338ea9dd3032d7c09a0c23f324b76229161c4133e75f1d6216be56681eee751fc008b63f06f1ba7ddff255657413cc9973f571c8c1f87237a3d814c04ced65b4438cf0fdb3034486815ad8f8e7bae927dbf8185b7dc1045b914b1
# Decrypted response: 67 62 66 83
# SENT RESPONSE: 67 62 66 83
# QUERY: 25 -> 17
# ENCRYPTED RESPONSE: 
# Decrypted response: 25 78 89 100 17
# SENT RESPONSE: 25 78 89 100 17
# QUERY: 111 -> 3
# ENCRYPTED RESPONSE: cda5c91fc6a42d0f2fd6ab0ad4ac0d68e8ae8868278cc2a1ebae62b3b84c795083ec9a5b81664fe36f0cc2f96aee636ac0146892b9ebb05340d94e1f2d733b93c3d17583d3520dcd19862fe66f9db657dd7d3b38c6cb3b840bd1325a13c8f9f9
# Decrypted response: 111 101 47 3
# SENT RESPONSE: 111 101 47 3
# QUERY: 6 -> 52
# ENCRYPTED RESPONSE: 
# Decrypted response: 6 22 113 87 117 10 52
# SENT RESPONSE: 6 22 113 87 117 10 52
# QUERY: 47 -> 64
# ENCRYPTED RESPONSE: 088aff1896d3a5e9b72c148c0646daf673060dc9fcecf4fc07f00ccfb2a9aaaa3c79b6bc66bbabdeb6b694bf957e0f1de8314a3334f168e1c9159785273041729aec42b9e5efa34a80ef12a367892727c630b10ae4a24badd2293ff0cd794ec4
# Decrypted response: 47 3 21 64
# SENT RESPONSE: 47 3 21 64
# > Original query: [+] Flag: SEKAI{GES_15_34sy_2_br34k_kn@w1ng_th3_k3y}
